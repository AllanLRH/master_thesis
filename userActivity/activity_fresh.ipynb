# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import re
sns.set(context='paper', style='whitegrid', color_codes=True, font_scale=1.8)
colorcycle = [(0.498, 0.788, 0.498),
              (0.745, 0.682, 0.831),
              (0.992, 0.753, 0.525),
              (0.220, 0.424, 0.690),
              (0.749, 0.357, 0.090),
              (1.000, 1.000, 0.600),
              (0.941, 0.008, 0.498),
              (0.400, 0.400, 0.400)]
sns.set_palette(colorcycle)
mpl.rcParams['figure.max_open_warning'] = 65
mpl.rcParams['figure.figsize'] = [12, 7]

from speclib import misc, plotting, loaders

# %matplotlib inline

# %%
df = pd.read_pickle('../../allan_data/phone_sms_and_call_dataframe.pkl')

df.head()
# Out:
#       aliasnumber                                      body comtype  duration  \
# user
# u0001        None  9e64d358966b4b36252009b860ce70e5a7ca26ce     sms       NaN
# u0001        None  6c41479beaa93097b8ce5f99735967b6ae980b79     sms       NaN
# u0001        None  5bab61eb53176449e25c2c82f172b82cb13ffb9d     sms       NaN
# u0001        None   a5b0b959e6b02c2e39c1a83eab80c47428662c9     sms       NaN
# u0001        None  94374cda78a133efeecda745670bc1df553a4071     sms       NaN
#
#                                          number           timestamp  type
# user
# u0001  b17d1b89a445e55f836075604488bfb0ef47ca76 2013-09-20 13:21:39     1
# u0001  c86591d48c99917acfcbe6e07d08ffc27544ea77 2013-10-12 16:00:04     1
# u0001  c86591d48c99917acfcbe6e07d08ffc27544ea77 2013-10-12 15:59:07     2
# u0001  c86591d48c99917acfcbe6e07d08ffc27544ea77 2013-10-12 15:59:02     2
# u0001  c86591d48c99917acfcbe6e07d08ffc27544ea77 2013-10-12 15:58:32     1

# %%
df.groupby(['comtype', df.timestamp.dt.weekday_name]).type.count().plot.bar()

# %%
df.groupby([df.timestamp.dt.weekday_name]).type.count().plot.bar()

# %%
df.groupby([df.timestamp.dt.hour]).type.count().plot.bar()

# %%
df = df[df.timestamp.dt.year >= 2013]

# %%
df.to_pickle('../../allan_data/phone_sms_and_call_dataframe.pkl')
