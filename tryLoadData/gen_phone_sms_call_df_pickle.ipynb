# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import re
sns.set(context='paper', style='whitegrid', color_codes=True, font_scale=1.8)
colorcycle = [(0.498, 0.788, 0.498),
              (0.745, 0.682, 0.831),
              (0.992, 0.753, 0.525),
              (0.220, 0.424, 0.690),
              (0.749, 0.357, 0.090),
              (1.000, 1.000, 0.600),
              (0.941, 0.008, 0.498),
              (0.400, 0.400, 0.400)]
sns.set_palette(colorcycle)
mpl.rcParams['figure.max_open_warning'] = 65
mpl.rcParams['figure.figsize'] = [12, 7]

from speclib import misc, plotting, loaders
import collections
import itertools

# %matplotlib inline

# %%
userlist = loaders.getUserList() 
useralias = loaders.Useralias()

# %%
load_args = [(name, useralias[name], ('call', 'sms')) for name in userlist]

user_dct = loaders.loadUserParallel(load_args)

# %%
phonebook = loaders.loadUserPhonenumberDict()
phonebook.setdefault(None)

# %%
df_lst = list()

for user in user_dct.keys():
    print(user)
    try:
        call = pd.DataFrame(user_dct[user]['call'])
        if sum(call.shape):
            call = call.rename(columns={'address': 'number'})
            call['timestamp'] = call.timestamp.astype('datetime64[s]')
            call['user'] = call.user.map(lambda us: useralias[us])
            mapper = lambda nb: useralias[phonebook.get(nb)] if phonebook.get(nb) is not None else None
            call['aliasnumber'] = call.number.map(mapper)
            call['comtype'] = 'call'
            call = call.drop('id', axis=1)

        sms = pd.DataFrame(user_dct[user]['sms'])
        if sum(sms.shape):
            sms = sms.rename(columns={'address': 'number'})
            sms['timestamp'] = sms.timestamp.astype('datetime64[s]')
            sms['user'] = sms.user.map(lambda us: useralias[us])
            mapper = lambda nb: useralias[phonebook.get(nb)] if phonebook.get(nb) is not None else None
            sms['aliasnumber'] = sms.number.map(mapper)
            sms['comtype'] = 'sms'
            sms = sms.drop('id', axis=1)
            
        df = pd.concat((call, sms)).set_index('user')
        df_lst.append(df)
    except KeyError:
        print("No data for user", user)
# Out:
# u0182
# u1015
# u0778
# u0933
# u0256
# u0659
# u0719
# u0709
# u0748
# u0045
# u0599
# u0346
# No data for user u0346
# u1027
# u0208
# u0316
# No data for user u0316
# u0059
# u0812
# u0954
# u0986
# No data for user u0986
# u0146
# u0862
# u0652
# u0350
# u0431
# u0793
# No data for user u0793
# u0093
# u0847
# u0001
# u0408
# u0328
# No data for user u0328
# u1056
# u0562
# u0100
# u0761
# u0013
# u0826
# u0456
# u0505
# u0493
# u0254
# No data for user u0254
# u0205
# u0801
# u0162
# No data for user u0162
# u0734
# u0238
# u0817
# u0797
# u0002
# No data for user u0002
# u0452
# u0213
# u0090
# u0077
# u0945
# u0438
# No data for user u0438
# u0402
# No data for user u0402
# u0395
# u0602
# u0136
# u1044
# No data for user u1044
# u0412
# u0313
# No data for user u0313
# u0243
# No data for user u0243
# u0347
# u0294
# u0201
# u0443
# u1005
# u0409
# u0156
# u0484
# u0952
# u0227
# No data for user u0227
# u0872
# u0051
# u0334
# u1021
# u0966
# u0198
# u0701
# u0379
# No data for user u0379
# u1032
# u0315
# u0095
# u0765
# No data for user u0765
# u0573
# No data for user u0573
# u0863
# u0115
# No data for user u0115
# u0856
# No data for user u0856
# u0672
# u0923
# u0258
# u0016
# u0400
# u0914
# No data for user u0914
# u0074
# u0110
# u0676
# u0339
# u0075
# No data for user u0075
# u0333
# No data for user u0333
# u0226
# No data for user u0226
# u1031
# No data for user u1031
# u0031
# No data for user u0031
# u0991
# u0828
# u0560
# u0473
# u0703
# u0417
# u0939
# u0808
# u0015
# u0489
# No data for user u0489
# u0927
# u0331
# u0730
# u0697
# u0494
# No data for user u0494
# u0670
# u0457
# u0279
# No data for user u0279
# u0597
# u0536
# u0142
# u0885
# u0874
# u0763
# u0931
# u0816
# u0371
# u0714
# No data for user u0714
# u1042
# u0215
# No data for user u0215
# u0665
# u0728
# u0649
# u0196
# u0171
# u0415
# u1036
# u0579
# u0518
# u0121
# u0460
# u0141
# u0922
# u0959
# u0298
# u0381
# u0707
# u0827
# u0880
# u0453
# u0343
# u1043
# u0762
# u0613
# u0299
# No data for user u0299
# u0623
# u0603
# No data for user u0603
# u0544
# u0165
# No data for user u0165
# u0572
# u0901
# u0464
# No data for user u0464
# u0928
# u0711
# u0446
# u0066
# u0225
# u0513
# u0740
# No data for user u0740
# u0855
# u0078
# u1013
# No data for user u1013
# u0423
# u0737
# u0444
# u0302
# No data for user u0302
# u0871
# u0694
# u1007
# u0539
# u0582
# u0989
# No data for user u0989
# u0324
# u0640
# u0297
# No data for user u0297
# u0726
# u0320
# u0193
# u0878
# u0442
# u0080
# u0021
# u0757
# u0741
# u0148
# No data for user u0148
# u0721
# u1054
# u0868
# u0157
# u0224
# u0158
# u0918
# u1019
# u0974
# u0534
# u0798
# u0361
# u0675
# u0259
# u0230
# No data for user u0230
# u0275
# u0246
# u0924
# u0955
# u0323
# No data for user u0323
# u0890
# u0211
# No data for user u0211
# u1038
# No data for user u1038
# u0129
# u0366
# u0420
# u0934
# u0349
# u0363
# u0017
# u0648
# u0976
# u0895
# u0372
# No data for user u0372
# u0980
# u0910
# u0627
# u0355
# u0996
# u0287
# u0743
# u0619
# u0662
# u0504
# No data for user u0504
# u0693
# u0736
# No data for user u0736
# u0897
# u0351
# u0596
# u0242
# u0253
# No data for user u0253
# u0638
# u0037
# u0419
# u0674
# u0814
# u0145
# No data for user u0145
# u0250
# u0574
# u0378
# No data for user u0378
# u0904
# u0293
# No data for user u0293
# u0486
# u0531
# u0244
# u0800
# u0295
# u0501
# No data for user u0501
# u0449
# u0176
# u0521
# u0804
# u0841
# u0951
# No data for user u0951
# u0892
# u0733
# u1041
# No data for user u1041
# u0938
# u0422
# No data for user u0422
# u0337
# u0516
# u0352
# u0887
# u0956
# u0664
# u0407
# u0789
# u0522
# No data for user u0522
# u0604
# u0656
# u0898
# u0981
# u0468
# u0510
# u0203
# u0658
# No data for user u0658
# u1028
# No data for user u1028
# u0580
# No data for user u0580
# u0706
# u0838
# No data for user u0838
# u0474
# u0432
# u0370
# No data for user u0370
# u1006
# No data for user u1006
# u0104
# u0760
# u0585
# u0292
# u0779
# u0281
# u0865
# u0127
# No data for user u0127
# u0485
# u0999
# u0791
# u0003
# u0175
# u0971
# No data for user u0971
# u0137
# u0962
# u0069
# u0678
# u0768
# u0692
# u0820
# u0650
# u0116
# u0101
# u0086
# u0702
# u1017
# No data for user u1017
# u0200
# u0907
# No data for user u0907
# u0497
# No data for user u0497
# u0005
# No data for user u0005
# u0925
# u0459
# u0630
# u0296
# u0909
# u0961
# No data for user u0961
# u0861
# u0977
# u0159
# u0471
# u0079
# u0849
# u0385
# No data for user u0385
# u0071
# No data for user u0071
# u0411
# u0310
# u0754
# u0163
# u0143
# u0236
# u1037
# u0174
# u0111
# u0006
# u0416
# No data for user u0416
# u0769
# u0478
# u0873
# u0807
# u0583
# No data for user u0583
# u0264
# u0436
# No data for user u0436
# u0851
# u0057
# u0327
# u0092
# u0039
# u0147
# No data for user u0147
# u0152
# No data for user u0152
# u0492
# u0884
# u0559
# u0512
# u0425
# No data for user u0425
# u0567
# u0835
# u0913
# u0199
# u1029
# u0009
# u0523
# u0963
# No data for user u0963
# u0308
# u0429
# u0433
# u0511
# u0653
# u0635
# u0020
# u0645
# u0633
# No data for user u0633
# u0014
# u0132
# u0753
# u0458
# u0836
# No data for user u0836
# u0811
# u0405
# No data for user u0405
# u0846
# u0248
# u0019
# u0717
# u0427
# No data for user u0427
# u0561
# u0832
# u0601
# u0348
# u0723
# u0752
# u0289
# u0140
# u0636
# u0607
# u0375
# u0117
# u0540
# u0802
# u0012
# u0274
# u0666
# u0944
# No data for user u0944
# u0669
# u0822
# No data for user u0822
# u0749
# u0360
# u0994
# u0937
# u0745
# u0499
# u0119
# No data for user u0119
# u0796
# No data for user u0796
# u1051
# u0858
# u0654
# No data for user u0654
# u1004
# u0040
# No data for user u0040
# u0618
# u0537
# u0233
# u0995
# u0984
# u0867
# u0821
# u0418
# u0777
# u0677
# u0616
# u0848
# u0168
# u0767
# No data for user u0767
# u0818
# u1008
# u1026
# u0685
# u0911
# No data for user u0911
# u0070
# u0985
# No data for user u0985
# u0318
# u0272
# u0950
# u0886
# u0035
# u0786
# u0448
# u0852
# No data for user u0852
# u0710
# No data for user u0710
# u0555
# No data for user u0555
# u0502
# No data for user u0502
# u0509
# u0553
# u0698
# No data for user u0698
# u0731
# u0028
# u0249
# u0068
# u0668
# u0063
# u0166
# No data for user u0166
# u1045
# u1002
# u0154
# u0441
# No data for user u0441
# u1049
# No data for user u1049
# u0584
# No data for user u0584
# u0393
# u0126
# u1014
# u0687
# u0837
# u0614
# u0357
# No data for user u0357
# u0428
# No data for user u0428
# u0879
# u0091
# u0547
# No data for user u0547
# u0139
# u0169
# No data for user u0169
# u0993
# u0533
# No data for user u0533
# u0454
# u0888
# u0479
# u0715
# u0061
# u0004
# u0122
# u0941
# u0514
# u1050
# u0273
# No data for user u0273
# u0261
# u0387
# u0932
# u0598
# u0997
# u0680
# No data for user u0680
# u0988
# u0421
# No data for user u0421
# u0251
# u0538
# No data for user u0538
# u0834
# No data for user u0834
# u0064
# u1000
# u0338
# No data for user u0338
# u0770
# u0545
# u0189
# u0144
# No data for user u0144
# u0414
# No data for user u0414
# u0595
# u0462
# No data for user u0462
# u0410
# u0247
# u0684
# No data for user u0684
# u0943
# u0373
# No data for user u0373
# u0739
# u0507
# u0644
# No data for user u0644
# u0833
# u0590
# u0344
# u0167
# u0894
# u0529
# u0926
# No data for user u0926
# u0097
# u0170
# u0686
# u0713
# u0161
# No data for user u0161
# u0608
# u0490
# No data for user u0490
# u0179
# u0082
# u1024
# No data for user u1024
# u0173
# u0430
# u0290
# u0575
# u1023
# u0578
# u0155
# u0356
# u0551
# u0682
# u0042
# No data for user u0042
# u1012
# u0626
# No data for user u0626
# u0109
# u0683
# u0439
# u0309
# u0192
# u0329
# u0688
# No data for user u0688
# u0099
# u0857
# u1001
# u0515
# u0970
# u0758
# u0342
# u0840
# u0482
# u0563
# u0899
# No data for user u0899
# u0593
# u0543
# u0588
# u0330
# No data for user u0330
# u0283
# u0790
# No data for user u0790
# u0022
# No data for user u0022
# u0564
# No data for user u0564
# u0218
# u0839
# No data for user u0839
# u0637
# u0651
# u0953
# No data for user u0953
# u0463
# u0815
# No data for user u0815
# u0424
# u0532
# u0708
# u0214
# u0882
# u0506
# u0704
# u0389
# u0335
# u0902
# u0581
# u0526
# u0033
# u0210
# u0969
# u0594
# u0130
# No data for user u0130
# u0217
# No data for user u0217
# u0570
# u0032
# u0620
# u1055
# u0081
# u0750
# u0105
# u0212
# u0690
# u0942
# u0362
# u0587
# No data for user u0587
# u0311
# u0399
# u0655
# u0113
# u0643
# u0467
# u0072
# u0605
# u0600
# u0825
# u0120
# u0475
# u0191
# No data for user u0191
# u0940
# u0232
# u0164
# u0689
# No data for user u0689
# u0062
# No data for user u0062
# u0089
# u1010
# u0755
# u0628
# u0487
# No data for user u0487
# u0556
# u0470
# u0724
# u0190
# u0365
# No data for user u0365
# u0824
# No data for user u0824
# u0391
# u0756
# No data for user u0756
# u0517
# No data for user u0517
# u0681
# u0131
# u0978
# u0270
# u0496
# u0982
# u0026
# u0241
# u1016
# u1035
# u0930
# No data for user u0930
# u0469
# No data for user u0469
# u0864
# u0341
# u0759
# u0027
# u0369
# u0843
# u0576
# u0695
# u0036
# u0957
# u0609
# u0673
# u0049
# u0784
# u1052
# u0223
# No data for user u0223
# u0663
# u0903
# u0124
# u0883
# u0992
# No data for user u0992
# u0314
# u0359
# No data for user u0359
# u0194
# u0735
# u0775
# u0054
# No data for user u0054
# u0266
# u0725
# u0776
# u0881
# u0782
# u0528
# No data for user u0528
# u0718
# u0967
# u0384
# u0228
# u0108
# u0434
# u0586
# u0606
# u1057
# u0806
# u0794
# u0667
# No data for user u0667
# u0566
# u0900
# u1058
# No data for user u1058
# u0252
# u0380
# No data for user u0380
# u0056
# u0052
# u0186
# No data for user u0186
# u1048
# No data for user u1048
# u0221
# u0679
# u0107
# u0114
# No data for user u0114
# u0525
# u0023
# u0742
# u0589
# No data for user u0589
# u0631
# u0413
# u0240
# u0483
# No data for user u0483
# u0935
# u0106
# u0799
# u0067
# No data for user u0067
# u0288
# u0639
# u0805
# No data for user u0805
# u0625
# u0831
# No data for user u0831
# u0859
# No data for user u0859
# u0476
# No data for user u0476
# u0773
# u0615
# No data for user u0615
# u0321
# u0979
# No data for user u0979
# u0530
# u0844
# u0466
# u0632
# u0908
# u0705
# No data for user u0705
# u0891
# u0265
# u0007
# u0919
# u0038
# No data for user u0038
# u0527
# u0406
# u0975
# u0508
# u0936
# u0065
# u0550
# u0271
# u0195
# u0671
# u0034
# u0727
# u0426
# u0819
# u0498
# u0150
# u0123
# No data for user u0123
# u0262
# u0083
# u0085
# u0276
# u0102
# u0617
# No data for user u0617
# u0291
# u0332
# u0322
# u0461
# u0916
# No data for user u0916
# u0948
# u0738
# u0641
# u0577
# u0103
# u0870
# No data for user u0870
# u0568
# u0118
# u0860
# u0374
# u0301
# No data for user u0301
# u0520
# u0437
# u0390
# u0440
# u0634
# u0751
# No data for user u0751
# u0435
# u0781
# u0998
# u0280
# No data for user u0280
# u0552
# No data for user u0552
# u0491
# u0785
# u0622
# u0747
# u0845
# u0263
# u0268
# No data for user u0268
# u0048
# u0376
# u0445
# u0055
# u0699
# u0503
# No data for user u0503
# u1025
# u0177
# u1011
# No data for user u1011
# u1033
# u0958
# u0285
# u0377
# u0896
# u0565
# u0312
# No data for user u0312
# u0803
# u0783
# u0729
# No data for user u0729
# u1046
# u0306
# u0772
# No data for user u0772
# u0987
# No data for user u0987
# u1039
# No data for user u1039
# u0245
# No data for user u0245
# u0229
# u0571
# u0133
# No data for user u0133
# u0172
# u0269
# u0611
# u0030
# u0178
# No data for user u0178
# u0792
# No data for user u0792
# u0746
# u0025
# u0774
# u0018
# u0303
# No data for user u0303
# u0624
# No data for user u0624
# u0696
# u0660
# u0780
# u0983
# u0535
# u0960
# u0197
# u0128
# u0592
# u0455
# u0153
# u0149
# u1018
# No data for user u1018
# u0500
# u0647
# u0612
# u0239
# u0403
# u0267
# u0921
# u0237
# u0345
# No data for user u0345
# u0138
# u0917
# u0326
# No data for user u0326
# u0787
# u0972
# No data for user u0972
# u1022
# u0869
# u0621
# u0876
# u0394
# u0788
# No data for user u0788
# u1053
# u0286
# No data for user u0286
# u0282
# u0830
# u0809
# u0661
# u0554
# u0112
# u0367
# u0465
# u0480
# u0481
# u0317
# u0388
# u0206
# u0875
# u0744
# u0548
# No data for user u0548
# u0477
# u0893
# u1047
# u0043
# u0011
# u0451
# u0386
# u0319
# No data for user u0319
# u0340
# u0220
# u0691
# u0915
# u0949
# u0160
# u0087
# u0047
# u0720
# u0401
# u0073
# u0008
# u0053
# u1020
# u0549
# u0354
# u0823
# u0187
# u0184
# No data for user u0184
# u0336
# u0050
# u0219
# u0134
# u0546
# u0364
# u0929
# u0207
# u0084
# u0766
# u0965
# No data for user u0965
# u0278
# u0076
# u0216
# No data for user u0216
# u1059
# u0524
# u0920
# u0304
# No data for user u0304
# u1009
# u0180
# No data for user u0180
# u0973
# u1034
# u0610
# No data for user u0610
# u0255
# No data for user u0255
# u0383
# u0325
# u0853
# u0722
# No data for user u0722
# u0558
# No data for user u0558
# u0094
# u0181
# u1030
# u0368
# u0096
# u0813
# No data for user u0813
# u0716
# No data for user u0716
# u0234
# u0905
# u0044
# u0947
# u0810
# u0646
# u0541
# u0358
# u0029
# u0222
# No data for user u0222
# u0591
# u1003
# u0495
# u0657
# u0058
# No data for user u0058
# u0024
# u0946
# u0397
# No data for user u0397
# u0098
# u0557
# u0151
# No data for user u0151
# u0889
# u0877
# u0866
# u0712
# No data for user u0712
# u0764
# u0569
# u0795
# u0629
# u0450
# u0046
# u0300
# u0519
# u0257
# No data for user u0257
# u0204
# u0396
# No data for user u0396
# u0472
# u0732
# u0829
# u0284
# u0642
# u0447
# u0231
# No data for user u0231
# u0771
# u0185
# No data for user u0185
# u0209
# u0850
# u0964
# u0010
# u0968
# No data for user u0968
# u0260
# u1040
# u0235
# u0277
# u0041
# u0700
# u0842
# u0135
# u0990
# No data for user u0990
# u0088
# u0542
# u0307
# u0183
# No data for user u0183
# u0912
# u0392
# u0398
# No data for user u0398
# u0305
# No data for user u0305
# u0060
# u0125
# u0854
# u0404
# u0202
# u0906
# No data for user u0906
# u0353
# u0382
# u0188
# u0488
# No data for user u0488

# %%
df = pd.concat(df_lst).sort_index()

# %%
df = df[df.timestamp.dt.year >= 2013]

# %%
df.to_pickle('../../allan_data/phone_sms_and_call_dataframe.pkl')
