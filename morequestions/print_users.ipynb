# %%
from string import Template

import sys
import os
sys.path.append(os.path.abspath(".."))

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import re
from IPython.display import display, HTML
sns.set(context='paper', style='whitegrid', color_codes=True, font_scale=1.8)
colorcycle = [(0.498, 0.788, 0.498),
              (0.745, 0.682, 0.831),
              (0.992, 0.753, 0.525),
              (0.220, 0.424, 0.690),
              (0.749, 0.357, 0.090),
              (1.000, 1.000, 0.600),
              (0.941, 0.008, 0.498),
              (0.400, 0.400, 0.400)]
sns.set_palette(colorcycle)
mpl.rcParams['figure.max_open_warning'] = 65
mpl.rcParams['figure.figsize'] = [12, 7]
mpl.rcParams['text.usetex'] = True

from speclib import misc, plotting, loaders

# %matplotlib inline

# %%
df = pd.read_json('../../allan_data/RGender_.json')
userAlias = loaders.Useralias()
df.index = df.index.map(lambda s: userAlias.lookup(s))
q = misc.QuestionCompleter(df)
f = misc.QuestionFilterer(df)

df.head()
# Out:
#                                 alcohol_binge10__answer  \
# 0010fedde8e61cad5b049da6df8b5a                      1.0
# 002ee26a0c38a1f77b7cdeab8046cd                      1.0
# 0037c93a19a7e90580086b462ba11b                      2.0
# 005b1e0298bde6b726156aefb8d88c                      1.0
# 00ad591e46eb6f3d8c474d9de9e219                      0.0
#
#                                alcohol_binge10__answer_type  \
# 0010fedde8e61cad5b049da6df8b5a                        radio
# 002ee26a0c38a1f77b7cdeab8046cd                        radio
# 0037c93a19a7e90580086b462ba11b                        radio
# 005b1e0298bde6b726156aefb8d88c                        radio
# 00ad591e46eb6f3d8c474d9de9e219                        radio
#
#                                                        alcohol_binge10__condition  \
# 0010fedde8e61cad5b049da6df8b5a  alcohol_debut != 'Jeg har aldrig drukket alkohol'
# 002ee26a0c38a1f77b7cdeab8046cd  alcohol_debut != 'Jeg har aldrig drukket alkohol'
# 0037c93a19a7e90580086b462ba11b  alcohol_debut != 'Jeg har aldrig drukket alkohol'
# 005b1e0298bde6b726156aefb8d88c  alcohol_debut != 'Jeg har aldrig drukket alkohol'
# 00ad591e46eb6f3d8c474d9de9e219  alcohol_debut != 'Jeg har aldrig drukket alkohol'
#
#                                                     alcohol_binge10__question  \
# 0010fedde8e61cad5b049da6df8b5a  Drukket mere end 10 genstande på en dag/aften
# 002ee26a0c38a1f77b7cdeab8046cd  Drukket mere end 10 genstande på en dag/aften
# 0037c93a19a7e90580086b462ba11b  Drukket mere end 10 genstande på en dag/aften
# 005b1e0298bde6b726156aefb8d88c  Drukket mere end 10 genstande på en dag/aften
# 00ad591e46eb6f3d8c474d9de9e219  Drukket mere end 10 genstande på en dag/aften
#
#                                alcohol_binge10__response  \
# 0010fedde8e61cad5b049da6df8b5a                   1 gange
# 002ee26a0c38a1f77b7cdeab8046cd                   1 gange
# 0037c93a19a7e90580086b462ba11b                   2 gange
# 005b1e0298bde6b726156aefb8d88c                   1 gange
# 00ad591e46eb6f3d8c474d9de9e219                   0 gange
#
#                                 alcohol_binge5__answer  \
# 0010fedde8e61cad5b049da6df8b5a                     2.0
# 002ee26a0c38a1f77b7cdeab8046cd                     0.0
# 0037c93a19a7e90580086b462ba11b                     2.0
# 005b1e0298bde6b726156aefb8d88c                     1.0
# 00ad591e46eb6f3d8c474d9de9e219                     1.0
#
#                                alcohol_binge5__answer_type  \
# 0010fedde8e61cad5b049da6df8b5a                       radio
# 002ee26a0c38a1f77b7cdeab8046cd                       radio
# 0037c93a19a7e90580086b462ba11b                       radio
# 005b1e0298bde6b726156aefb8d88c                       radio
# 00ad591e46eb6f3d8c474d9de9e219                       radio
#
#                                                         alcohol_binge5__condition  \
# 0010fedde8e61cad5b049da6df8b5a  alcohol_debut != 'Jeg har aldrig drukket alkohol'
# 002ee26a0c38a1f77b7cdeab8046cd  alcohol_debut != 'Jeg har aldrig drukket alkohol'
# 0037c93a19a7e90580086b462ba11b  alcohol_debut != 'Jeg har aldrig drukket alkohol'
# 005b1e0298bde6b726156aefb8d88c  alcohol_debut != 'Jeg har aldrig drukket alkohol'
# 00ad591e46eb6f3d8c474d9de9e219  alcohol_debut != 'Jeg har aldrig drukket alkohol'
#
#                                                     alcohol_binge5__question  \
# 0010fedde8e61cad5b049da6df8b5a  Drukket mere end 5 genstande på en dag/aften
# 002ee26a0c38a1f77b7cdeab8046cd  Drukket mere end 5 genstande på en dag/aften
# 0037c93a19a7e90580086b462ba11b  Drukket mere end 5 genstande på en dag/aften
# 005b1e0298bde6b726156aefb8d88c  Drukket mere end 5 genstande på en dag/aften
# 00ad591e46eb6f3d8c474d9de9e219  Drukket mere end 5 genstande på en dag/aften
#
#                                alcohol_binge5__response  \
# 0010fedde8e61cad5b049da6df8b5a                  2 gange
# 002ee26a0c38a1f77b7cdeab8046cd                  0 gange
# 0037c93a19a7e90580086b462ba11b                  2 gange
# 005b1e0298bde6b726156aefb8d88c                  1 gange
# 00ad591e46eb6f3d8c474d9de9e219                  1 gange
#
#                                            ...              \
# 0010fedde8e61cad5b049da6df8b5a             ...
# 002ee26a0c38a1f77b7cdeab8046cd             ...
# 0037c93a19a7e90580086b462ba11b             ...
# 005b1e0298bde6b726156aefb8d88c             ...
# 00ad591e46eb6f3d8c474d9de9e219             ...
#
#                                 worries_partner__answer  \
# 0010fedde8e61cad5b049da6df8b5a                      NaN
# 002ee26a0c38a1f77b7cdeab8046cd                      2.0
# 0037c93a19a7e90580086b462ba11b                      NaN
# 005b1e0298bde6b726156aefb8d88c                      NaN
# 00ad591e46eb6f3d8c474d9de9e219                      2.0
#
#                                worries_partner__answer_type  \
# 0010fedde8e61cad5b049da6df8b5a                        radio
# 002ee26a0c38a1f77b7cdeab8046cd                        radio
# 0037c93a19a7e90580086b462ba11b                        radio
# 005b1e0298bde6b726156aefb8d88c                        radio
# 00ad591e46eb6f3d8c474d9de9e219                        radio
#
#                                 worries_partner__condition  \
# 0010fedde8e61cad5b049da6df8b5a                       False
# 002ee26a0c38a1f77b7cdeab8046cd                       False
# 0037c93a19a7e90580086b462ba11b                       False
# 005b1e0298bde6b726156aefb8d88c                       False
# 00ad591e46eb6f3d8c474d9de9e219                       False
#
#                                worries_partner__question  \
# 0010fedde8e61cad5b049da6df8b5a         Kæreste/ægtefælle
# 002ee26a0c38a1f77b7cdeab8046cd         Kæreste/ægtefælle
# 0037c93a19a7e90580086b462ba11b         Kæreste/ægtefælle
# 005b1e0298bde6b726156aefb8d88c         Kæreste/ægtefælle
# 00ad591e46eb6f3d8c474d9de9e219         Kæreste/ægtefælle
#
#                                worries_partner__response  \
# 0010fedde8e61cad5b049da6df8b5a                 Har ingen
# 002ee26a0c38a1f77b7cdeab8046cd                 Af og til
# 0037c93a19a7e90580086b462ba11b                 Har ingen
# 005b1e0298bde6b726156aefb8d88c                 Har ingen
# 00ad591e46eb6f3d8c474d9de9e219                 Af og til
#
#                                 worries_zieblings__answer  \
# 0010fedde8e61cad5b049da6df8b5a                        3.0
# 002ee26a0c38a1f77b7cdeab8046cd                        NaN
# 0037c93a19a7e90580086b462ba11b                        2.0
# 005b1e0298bde6b726156aefb8d88c                        NaN
# 00ad591e46eb6f3d8c474d9de9e219                        3.0
#
#                                worries_zieblings__answer_type  \
# 0010fedde8e61cad5b049da6df8b5a                          radio
# 002ee26a0c38a1f77b7cdeab8046cd                          radio
# 0037c93a19a7e90580086b462ba11b                          radio
# 005b1e0298bde6b726156aefb8d88c                          radio
# 00ad591e46eb6f3d8c474d9de9e219                          radio
#
#                                worries_zieblings__condition  \
# 0010fedde8e61cad5b049da6df8b5a                        False
# 002ee26a0c38a1f77b7cdeab8046cd                        False
# 0037c93a19a7e90580086b462ba11b                        False
# 005b1e0298bde6b726156aefb8d88c                        False
# 00ad591e46eb6f3d8c474d9de9e219                        False
#
#                                worries_zieblings__question  \
# 0010fedde8e61cad5b049da6df8b5a                    Søskende
# 002ee26a0c38a1f77b7cdeab8046cd                    Søskende
# 0037c93a19a7e90580086b462ba11b                    Søskende
# 005b1e0298bde6b726156aefb8d88c                    Søskende
# 00ad591e46eb6f3d8c474d9de9e219                    Søskende
#
#                                worries_zieblings__response
# 0010fedde8e61cad5b049da6df8b5a                    Sjældent
# 002ee26a0c38a1f77b7cdeab8046cd                   Har ingen
# 0037c93a19a7e90580086b462ba11b                   Af og til
# 005b1e0298bde6b726156aefb8d88c                   Har ingen
# 00ad591e46eb6f3d8c474d9de9e219                    Sjældent
#
# [5 rows x 1431 columns]

# %%
misc.questionSummary(df, q.alcohol_binge10)
# Out:
# <h3><i>Question:</i>  Drukket mere end 10 genstande på en dag/aften</h3>
# <i>Question str:</i>    <tt>alcohol_binge10</tt>
# <i>Answer type:</i>    <tt>radio</tt>
#   response_index  answer_index  count
# 0        0 gange           0.0    348
# 1        1 gange           1.0    190
# 2        2 gange           2.0    151
# 3        3 gange           3.0     89
# 4      4-5 gange           4.0     74
# 5       6+ gange           5.0     54

# %%
def get_question_tex(df, qstr):
    dct = misc.questionSummary(df, qstr, display_summary=False)
    dct['question_str'] = dct['question_str'].replace(r'_', r'\_')
    ra = dct['resp_ans'] 
    ra['answer_index'] = ra.answer_index.astype(int)

    tmpl_str = r"""
\begin{minipage}{0.4\textwidth}
\vspace{1cm}
\section*{\texttt{\textbf{$question_str}}}

\begin{description}
  \item[Question]  $question
  \item[Answer type]  \verb|$answer_type|
\end{description}


"""

    tmpl = Template(tmpl_str)
    ret = tmpl.substitute(dct) 
    ret = ret + ra.to_latex()
    ret = ret + "\n \\end{minipage}"

    return ret

# %%
qlst = list()
for el in df.columns:
    qstr = el.split('__')[0]
    if qstr not in qlst and qstr != 'gender':
        qlst.append(qstr)

# %%
# qstr_set = set([el.split('__')[0] for el in df.columns if el != 'gender'])

# %%
tex_questions_str = [get_question_tex(df, el) for el in qlst]

# %%
tex_str = r"""\input{questionsummaryPreamble}

\begin{document}
\pagestyle{fancy}
% \thispagestyle{firstPageStyle}
\hyphenation{fortran super-conducting}
\selectlanguage{english}
\title{\Huge{\textbf{\sffamily{Question summary}}} \\
\Large{\textbf{\sffamily{Checking for reversed scales}}}}
\author{Allan L. R. Hansen}
\date{\today}
% \maketitle

ÅÅÅ_contents


\end{document}
"""

# %%
tex_main_str = tex_str.replace('ÅÅÅ_contents', '\n\n\n'.join(tex_questions_str))

# %%
with open('question_summary_tex/question_summary_main.tex', 'w') as fid:
    fid.write(tex_main_str)

# %%
print(tex_questions_str[0])
# Out:
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_binge10}}}
#
# \begin{description}
#   \item[Question]  Drukket mere end 10 genstande på en dag/aften
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &        0 gange &             0 &    348 \\
# 1 &        1 gange &             1 &    190 \\
# 2 &        2 gange &             2 &    151 \\
# 3 &        3 gange &             3 &     89 \\
# 4 &      4-5 gange &             4 &     74 \\
# 5 &       6+ gange &             5 &     54 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}

# %%
print(tex_main_str)
# Out:
# \input{questionsummaryPreamble}
#
# \begin{document}
# \pagestyle{fancy}
# % \thispagestyle{firstPageStyle}
# \hyphenation{fortran super-conducting}
# \selectlanguage{english}
# \title{\Huge{\textbf{\sffamily{Question summary}}} \\
# \Large{\textbf{\sffamily{Checking for reversed scales}}}}
# \author{Allan L. R. Hansen}
# \date{\today}
# % \maketitle
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_binge10}}}
#
# \begin{description}
#   \item[Question]  Drukket mere end 10 genstande på en dag/aften
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &        0 gange &             0 &    348 \\
# 1 &        1 gange &             1 &    190 \\
# 2 &        2 gange &             2 &    151 \\
# 3 &        3 gange &             3 &     89 \\
# 4 &      4-5 gange &             4 &     74 \\
# 5 &       6+ gange &             5 &     54 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_binge5}}}
#
# \begin{description}
#   \item[Question]  Drukket mere end 5 genstande på en dag/aften
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &        0 gange &             0 &    183 \\
# 1 &        1 gange &             1 &    189 \\
# 2 &        2 gange &             2 &    165 \\
# 3 &        3 gange &             3 &    153 \\
# 4 &      4-5 gange &             4 &    120 \\
# 5 &       6+ gange &             5 &     96 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_debut}}}
#
# \begin{description}
#   \item[Question]  Hvor gammel var du første gang du drak mindst en genstand?
#   \item[Answer type]  \verb|number;radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &             14 &             0 &     34 \\
# 1 &             15 &             1 &    906 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_drunk}}}
#
# \begin{description}
#   \item[Question]  Hvor mange gange er du blevet fuld af at drikke alkohol i løbet af  <u>de sidste 30 dage</u>?
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &        0 gange &             0 &    135 \\
# 1 &        1 gange &             1 &    124 \\
# 2 &        2 gange &             2 &    155 \\
# 3 &        3 gange &             3 &    120 \\
# 4 &      4-5 gange &             4 &    187 \\
# 5 &      6-9 gange &             5 &    136 \\
# 6 &      10+ gange &             6 &     49 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_everyday}}}
#
# \begin{description}
#   \item[Question]  Drukket dig fuld på en hverdagsaften/dag, hvor du skulle i skole eller på dit fuldtidsjob dagen efter
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &        0 gange &             0 &    762 \\
# 1 &        1 gange &             1 &     99 \\
# 2 &        2 gange &             2 &     25 \\
# 3 &        3 gange &             3 &     11 \\
# 4 &      4-5 gange &             4 &      3 \\
# 5 &       6+ gange &             5 &      6 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_very\_drunk}}}
#
# \begin{description}
#   \item[Question]  Drukket dig meget fuld
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &        0 gange &             0 &    309 \\
# 1 &        1 gange &             1 &    216 \\
# 2 &        2 gange &             2 &    155 \\
# 3 &        3 gange &             3 &     97 \\
# 4 &      4-5 gange &             4 &     92 \\
# 5 &       6+ gange &             5 &     37 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_volume\_friday}}}
#
# \begin{description}
#   \item[Question]
#   \item[Answer type]  \verb|number|
# \end{description}
#
#
# \begin{tabular}{lrrr}
# \toprule
# {} &  response\_index &  answer\_index &  count \\
# \midrule
# 0  &             0.0 &             0 &    394 \\
# 1  &             1.0 &             1 &     63 \\
# 2  &             2.0 &             2 &     58 \\
# 3  &             3.0 &             3 &     25 \\
# 4  &             4.0 &             4 &     32 \\
# 5  &             5.0 &             5 &     36 \\
# 6  &             6.0 &             6 &     27 \\
# 7  &             7.0 &             7 &     24 \\
# 8  &             8.0 &             8 &     35 \\
# 9  &             9.0 &             9 &     12 \\
# 10 &            10.0 &            10 &     56 \\
# 11 &            11.0 &            11 &      4 \\
# 12 &            12.0 &            12 &     31 \\
# 13 &            13.0 &            13 &     10 \\
# 14 &            14.0 &            14 &     12 \\
# 15 &            15.0 &            15 &     40 \\
# 16 &            16.0 &            16 &      4 \\
# 17 &            17.0 &            17 &      3 \\
# 18 &            18.0 &            18 &      4 \\
# 19 &            19.0 &            19 &      4 \\
# 20 &            20.0 &            20 &     22 \\
# 21 &            21.0 &            21 &      1 \\
# 22 &            22.0 &            22 &      1 \\
# 23 &            25.0 &            25 &      6 \\
# 24 &            30.0 &            30 &      2 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_volume\_monday}}}
#
# \begin{description}
#   \item[Question]
#   \item[Answer type]  \verb|number|
# \end{description}
#
#
# \begin{tabular}{lrrr}
# \toprule
# {} &  response\_index &  answer\_index &  count \\
# \midrule
# 0  &             0.0 &             0 &    786 \\
# 1  &             1.0 &             1 &     36 \\
# 2  &             2.0 &             2 &     25 \\
# 3  &             3.0 &             3 &     15 \\
# 4  &             4.0 &             4 &      7 \\
# 5  &             5.0 &             5 &      6 \\
# 6  &             6.0 &             6 &      7 \\
# 7  &             7.0 &             7 &      2 \\
# 8  &             8.0 &             8 &      6 \\
# 9  &             9.0 &             9 &      1 \\
# 10 &            10.0 &            10 &      6 \\
# 11 &            11.0 &            11 &      1 \\
# 12 &            14.0 &            14 &      2 \\
# 13 &            15.0 &            15 &      3 \\
# 14 &            20.0 &            20 &      3 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_volume\_saturday}}}
#
# \begin{description}
#   \item[Question]
#   \item[Answer type]  \verb|number|
# \end{description}
#
#
# \begin{tabular}{lrrr}
# \toprule
# {} &  response\_index &  answer\_index &  count \\
# \midrule
# 0  &             0.0 &             0 &    507 \\
# 1  &             1.0 &             1 &     64 \\
# 2  &             2.0 &             2 &     57 \\
# 3  &             3.0 &             3 &     36 \\
# 4  &             4.0 &             4 &     13 \\
# 5  &             5.0 &             5 &     26 \\
# 6  &             6.0 &             6 &     22 \\
# 7  &             7.0 &             7 &     12 \\
# 8  &             8.0 &             8 &     28 \\
# 9  &             9.0 &             9 &     10 \\
# 10 &            10.0 &            10 &     40 \\
# 11 &            11.0 &            11 &      4 \\
# 12 &            12.0 &            12 &     11 \\
# 13 &            13.0 &            13 &      3 \\
# 14 &            14.0 &            14 &      5 \\
# 15 &            15.0 &            15 &     31 \\
# 16 &            16.0 &            16 &      5 \\
# 17 &            17.0 &            17 &      4 \\
# 18 &            18.0 &            18 &      3 \\
# 19 &            19.0 &            19 &      2 \\
# 20 &            20.0 &            20 &     12 \\
# 21 &            22.0 &            22 &      1 \\
# 22 &            25.0 &            25 &      5 \\
# 23 &            27.0 &            27 &      1 \\
# 24 &            30.0 &            30 &      3 \\
# 25 &            34.0 &            34 &      1 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_volume\_sunday}}}
#
# \begin{description}
#   \item[Question]
#   \item[Answer type]  \verb|number|
# \end{description}
#
#
# \begin{tabular}{lrrr}
# \toprule
# {} &  response\_index &  answer\_index &  count \\
# \midrule
# 0  &             0.0 &             0 &    778 \\
# 1  &             1.0 &             1 &     44 \\
# 2  &             2.0 &             2 &     33 \\
# 3  &             3.0 &             3 &     16 \\
# 4  &             4.0 &             4 &      6 \\
# 5  &             5.0 &             5 &     10 \\
# 6  &             6.0 &             6 &      6 \\
# 7  &             7.0 &             7 &      1 \\
# 8  &             8.0 &             8 &      1 \\
# 9  &            10.0 &            10 &      3 \\
# 10 &            11.0 &            11 &      1 \\
# 11 &            12.0 &            12 &      1 \\
# 12 &            15.0 &            15 &      1 \\
# 13 &            16.0 &            16 &      1 \\
# 14 &            19.0 &            19 &      3 \\
# 15 &            20.0 &            20 &      1 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_volume\_thursday}}}
#
# \begin{description}
#   \item[Question]
#   \item[Answer type]  \verb|number|
# \end{description}
#
#
# \begin{tabular}{lrrr}
# \toprule
# {} &  response\_index &  answer\_index &  count \\
# \midrule
# 0  &             0.0 &             0 &    668 \\
# 1  &             1.0 &             1 &     52 \\
# 2  &             2.0 &             2 &     27 \\
# 3  &             3.0 &             3 &     16 \\
# 4  &             4.0 &             4 &     13 \\
# 5  &             5.0 &             5 &      9 \\
# 6  &             6.0 &             6 &     15 \\
# 7  &             7.0 &             7 &      9 \\
# 8  &             8.0 &             8 &     10 \\
# 9  &             9.0 &             9 &      4 \\
# 10 &            10.0 &            10 &     23 \\
# 11 &            11.0 &            11 &      5 \\
# 12 &            12.0 &            12 &      8 \\
# 13 &            13.0 &            13 &      1 \\
# 14 &            14.0 &            14 &      5 \\
# 15 &            15.0 &            15 &     13 \\
# 16 &            16.0 &            16 &      1 \\
# 17 &            18.0 &            18 &      4 \\
# 18 &            19.0 &            19 &      1 \\
# 19 &            20.0 &            20 &     16 \\
# 20 &            22.0 &            22 &      1 \\
# 21 &            25.0 &            25 &      3 \\
# 22 &            30.0 &            30 &      1 \\
# 23 &            35.0 &            35 &      1 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_volume\_tuesday}}}
#
# \begin{description}
#   \item[Question]
#   \item[Answer type]  \verb|number|
# \end{description}
#
#
# \begin{tabular}{lrrr}
# \toprule
# {} &  response\_index &  answer\_index &  count \\
# \midrule
# 0  &             0.0 &             0 &    709 \\
# 1  &             1.0 &             1 &     44 \\
# 2  &             2.0 &             2 &     27 \\
# 3  &             3.0 &             3 &     15 \\
# 4  &             4.0 &             4 &      7 \\
# 5  &             5.0 &             5 &      7 \\
# 6  &             6.0 &             6 &      7 \\
# 7  &             7.0 &             7 &      8 \\
# 8  &             8.0 &             8 &     13 \\
# 9  &             9.0 &             9 &      1 \\
# 10 &            10.0 &            10 &     23 \\
# 11 &            11.0 &            11 &      1 \\
# 12 &            12.0 &            12 &     10 \\
# 13 &            13.0 &            13 &      2 \\
# 14 &            14.0 &            14 &      2 \\
# 15 &            15.0 &            15 &     17 \\
# 16 &            17.0 &            17 &      1 \\
# 17 &            20.0 &            20 &      8 \\
# 18 &            22.0 &            22 &      1 \\
# 19 &            25.0 &            25 &      2 \\
# 20 &            30.0 &            30 &      1 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_volume\_wednesday}}}
#
# \begin{description}
#   \item[Question]
#   \item[Answer type]  \verb|number|
# \end{description}
#
#
# \begin{tabular}{lrrr}
# \toprule
# {} &  response\_index &  answer\_index &  count \\
# \midrule
# 0  &             0.0 &             0 &    708 \\
# 1  &             0.5 &             0 &      1 \\
# 2  &             1.0 &             1 &     51 \\
# 3  &             2.0 &             2 &     20 \\
# 4  &             3.0 &             3 &     17 \\
# 5  &             4.0 &             4 &      8 \\
# 6  &             5.0 &             5 &     10 \\
# 7  &             6.0 &             6 &      5 \\
# 8  &             7.0 &             7 &      7 \\
# 9  &             8.0 &             8 &      9 \\
# 10 &             9.0 &             9 &      5 \\
# 11 &            10.0 &            10 &     18 \\
# 12 &            11.0 &            11 &      1 \\
# 13 &            12.0 &            12 &      7 \\
# 14 &            13.0 &            13 &      3 \\
# 15 &            14.0 &            14 &      1 \\
# 16 &            15.0 &            15 &     14 \\
# 17 &            16.0 &            16 &      1 \\
# 18 &            18.0 &            18 &      4 \\
# 19 &            20.0 &            20 &     13 \\
# 20 &            25.0 &            25 &      2 \\
# 21 &            30.0 &            30 &      1 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{alcohol\_weekend}}}
#
# \begin{description}
#   \item[Question]  Drukket alkohol i weekenden
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &        0 gange &             0 &    113 \\
# 1 &        1 gange &             1 &    158 \\
# 2 &        2 gange &             2 &    201 \\
# 3 &        3 gange &             3 &    173 \\
# 4 &      4-5 gange &             4 &    184 \\
# 5 &       6+ gange &             5 &     77 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{ambition\_career}}}
#
# \begin{description}
#   \item[Question]  Hvor vigtig er din faglige karriere for dig i forhold til andre ting i dit liv såsom venner, familie, fritid?
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &                                     response\_index &  answer\_index &  count \\
# \midrule
# 0 &        Min faglige karriere er klart det vigtigste &             0 &     47 \\
# 1 &  Min faglige karriere er nok lidt mere vigtig e... &             1 &    293 \\
# 2 &  Min faglige karriere er lige så vigtig som and... &             2 &    455 \\
# 3 &  Min faglige karriere er nok ikke lige så vigti... &             3 &    122 \\
# 4 &  Andre ting er klart vigtigere en min faglige k... &             4 &     25 \\
# 5 &                                           ved ikke &             5 &      8 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{ambition\_job}}}
#
# \begin{description}
#   \item[Question]  Hvor vigtige tror du, at dine karakterer på det første år, er for det job du godt kunne tænke dig, når du er færdig med uddannelsen?
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &                                     response\_index &  answer\_index &  count \\
# \midrule
# 0 &  Det er afgørende at jeg får rigtig gode karakt... &             0 &     37 \\
# 1 &  Det er muligvis vigtigt at jeg får gode karakt... &             1 &    220 \\
# 2 &  Mine karakterer på første år er nok ikke særli... &             2 &    431 \\
# 3 &  Mine karakterer på første år betyder slet ikke... &             3 &    163 \\
# 4 &  Jeg ved ikke hvilket job jeg kunne tænke mig e... &             4 &     80 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{ambition\_mark}}}
#
# \begin{description}
#   \item[Question]  Hvor meget betyder dine karakterer for dig?
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &                              response\_index &  answer\_index &  count \\
# \midrule
# 0 &    Mine karakterer er meget vigtige for mig &             0 &    149 \\
# 1 &          Mine karakterer er vigtige for mig &             1 &    574 \\
# 2 &  Mine karakterer er ikke så vigtige for mig &             2 &    210 \\
# 3 &                                    Ved ikke &             3 &      8 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bf\_complet}}}
#
# \begin{description}
#   \item[Question]  lægger planer og får dem gennemført
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     10 \\
# 1 &                     Uenig &             1 &    113 \\
# 2 &  Hverken enig eller uenig &             2 &    327 \\
# 3 &                      Enig &             3 &    413 \\
# 4 &                Meget enig &             4 &     79 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_art}}}
#
# \begin{description}
#   \item[Question]  værdsætter kunstneriske, æstetiske oplevelser
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     52 \\
# 1 &                     Uenig &             1 &    164 \\
# 2 &  Hverken enig eller uenig &             2 &    222 \\
# 3 &                      Enig &             3 &    329 \\
# 4 &                Meget enig &             4 &    175 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_calm}}}
#
# \begin{description}
#   \item[Question]  bevarer roen i anspændte situationer
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      4 \\
# 1 &                     Uenig &             1 &     51 \\
# 2 &  Hverken enig eller uenig &             2 &    231 \\
# 3 &                      Enig &             3 &    495 \\
# 4 &                Meget enig &             4 &    161 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_careless}}}
#
# \begin{description}
#   \item[Question]  kan være noget skødesløs
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    119 \\
# 1 &                     Uenig &             1 &    297 \\
# 2 &  Hverken enig eller uenig &             2 &    343 \\
# 3 &                      Enig &             3 &    160 \\
# 4 &                Meget enig &             4 &     23 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_caring}}}
#
# \begin{description}
#   \item[Question]  er omsorgsfuld og venlig over for næsten alle
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      5 \\
# 1 &                     Uenig &             1 &     26 \\
# 2 &  Hverken enig eller uenig &             2 &    124 \\
# 3 &                      Enig &             3 &    540 \\
# 4 &                Meget enig &             4 &    247 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_cold}}}
#
# \begin{description}
#   \item[Question]  kan være kold og distanceret
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    158 \\
# 1 &                     Uenig &             1 &    338 \\
# 2 &  Hverken enig eller uenig &             2 &    241 \\
# 3 &                      Enig &             3 &    181 \\
# 4 &                Meget enig &             4 &     24 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_confident}}}
#
# \begin{description}
#   \item[Question]  almindeligvis er tillidsfuld
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      5 \\
# 1 &                     Uenig &             1 &     16 \\
# 2 &  Hverken enig eller uenig &             2 &     74 \\
# 3 &                      Enig &             3 &    563 \\
# 4 &                Meget enig &             4 &    284 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_coorporation}}}
#
# \begin{description}
#   \item[Question]  kan lide at samarbejde med andre
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      7 \\
# 1 &                     Uenig &             1 &     44 \\
# 2 &  Hverken enig eller uenig &             2 &    188 \\
# 3 &                      Enig &             3 &    527 \\
# 4 &                Meget enig &             4 &    176 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_creative}}}
#
# \begin{description}
#   \item[Question]  tænker kreativt og grundigt
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      5 \\
# 1 &                     Uenig &             1 &     54 \\
# 2 &  Hverken enig eller uenig &             2 &    240 \\
# 3 &                      Enig &             3 &    504 \\
# 4 &                Meget enig &             4 &    139 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_currious}}}
#
# \begin{description}
#   \item[Question]  er nysgerrig og interesseret i mange forskellige ting
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      3 \\
# 1 &                     Uenig &             1 &     19 \\
# 2 &  Hverken enig eller uenig &             2 &     69 \\
# 3 &                      Enig &             3 &    454 \\
# 4 &                Meget enig &             4 &    397 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_depressed}}}
#
# \begin{description}
#   \item[Question]  er deprimeret, nedtrykt
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    302 \\
# 1 &                     Uenig &             1 &    362 \\
# 2 &  Hverken enig eller uenig &             2 &    201 \\
# 3 &                      Enig &             3 &     68 \\
# 4 &                Meget enig &             4 &      9 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_disorderly}}}
#
# \begin{description}
#   \item[Question]  ofte er ustruktureret
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    135 \\
# 1 &                     Uenig &             1 &    263 \\
# 2 &  Hverken enig eller uenig &             2 &    228 \\
# 3 &                      Enig &             3 &    243 \\
# 4 &                Meget enig &             4 &     73 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_distract}}}
#
# \begin{description}
#   \item[Question]  let lader sig distrahere
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     36 \\
# 1 &                     Uenig &             1 &    212 \\
# 2 &  Hverken enig eller uenig &             2 &    285 \\
# 3 &                      Enig &             3 &    318 \\
# 4 &                Meget enig &             4 &     91 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_effective}}}
#
# \begin{description}
#   \item[Question]  er effektiv
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      7 \\
# 1 &                     Uenig &             1 &     65 \\
# 2 &  Hverken enig eller uenig &             2 &    214 \\
# 3 &                      Enig &             3 &    517 \\
# 4 &                Meget enig &             4 &    139 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_energi}}}
#
# \begin{description}
#   \item[Question]  er fuld af energi
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     10 \\
# 1 &                     Uenig &             1 &     99 \\
# 2 &  Hverken enig eller uenig &             2 &    329 \\
# 3 &                      Enig &             3 &    375 \\
# 4 &                Meget enig &             4 &    129 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_enthusiasm}}}
#
# \begin{description}
#   \item[Question]  ofte vækker begejstring
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      5 \\
# 1 &                     Uenig &             1 &     84 \\
# 2 &  Hverken enig eller uenig &             2 &    430 \\
# 3 &                      Enig &             3 &    340 \\
# 4 &                Meget enig &             4 &     83 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_error}}}
#
# \begin{description}
#   \item[Question]  ofte finder fejl ved andre
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     36 \\
# 1 &                     Uenig &             1 &    216 \\
# 2 &  Hverken enig eller uenig &             2 &    319 \\
# 3 &                      Enig &             3 &    331 \\
# 4 &                Meget enig &             4 &     40 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_few\_art}}}
#
# \begin{description}
#   \item[Question]  har få kunstneriske interesser
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    108 \\
# 1 &                     Uenig &             1 &    215 \\
# 2 &  Hverken enig eller uenig &             2 &    246 \\
# 3 &                      Enig &             3 &    282 \\
# 4 &                Meget enig &             4 &     91 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_fight}}}
#
# \begin{description}
#   \item[Question]  kommer op at skændes med andre
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    392 \\
# 1 &                     Uenig &             1 &    388 \\
# 2 &  Hverken enig eller uenig &             2 &    123 \\
# 3 &                      Enig &             3 &     34 \\
# 4 &                Meget enig &             4 &      5 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_forgive}}}
#
# \begin{description}
#   \item[Question]  har let ved at tilgive
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     21 \\
# 1 &                     Uenig &             1 &     88 \\
# 2 &  Hverken enig eller uenig &             2 &    173 \\
# 3 &                      Enig &             3 &    431 \\
# 4 &                Meget enig &             4 &    229 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_helpfull}}}
#
# \begin{description}
#   \item[Question]  er hjælpsom og uselvisk overfor andre
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      4 \\
# 1 &                     Uenig &             1 &     31 \\
# 2 &  Hverken enig eller uenig &             2 &    147 \\
# 3 &                      Enig &             3 &    568 \\
# 4 &                Meget enig &             4 &    192 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_hold\_on}}}
#
# \begin{description}
#   \item[Question]  holder ved indtil en opgave er fuldført
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      8 \\
# 1 &                     Uenig &             1 &     64 \\
# 2 &  Hverken enig eller uenig &             2 &    234 \\
# 3 &                      Enig &             3 &    455 \\
# 4 &                Meget enig &             4 &    181 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_imagination}}}
#
# \begin{description}
#   \item[Question]  har en livlig fantasi
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     14 \\
# 1 &                     Uenig &             1 &     98 \\
# 2 &  Hverken enig eller uenig &             2 &    244 \\
# 3 &                      Enig &             3 &    396 \\
# 4 &                Meget enig &             4 &    190 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_inventive}}}
#
# \begin{description}
#   \item[Question]  er opfindsom
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      6 \\
# 1 &                     Uenig &             1 &     57 \\
# 2 &  Hverken enig eller uenig &             2 &    264 \\
# 3 &                      Enig &             3 &    497 \\
# 4 &                Meget enig &             4 &    118 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_lazy}}}
#
# \begin{description}
#   \item[Question]  er tilbøjelig til at være doven
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     53 \\
# 1 &                     Uenig &             1 &    188 \\
# 2 &  Hverken enig eller uenig &             2 &    254 \\
# 3 &                      Enig &             3 &    348 \\
# 4 &                Meget enig &             4 &     99 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_nervous}}}
#
# \begin{description}
#   \item[Question]  let bliver nervøs
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    101 \\
# 1 &                     Uenig &             1 &    306 \\
# 2 &  Hverken enig eller uenig &             2 &    259 \\
# 3 &                      Enig &             3 &    235 \\
# 4 &                Meget enig &             4 &     41 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_original}}}
#
# \begin{description}
#   \item[Question]  er original, kommer med nye ideer
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      7 \\
# 1 &                     Uenig &             1 &     72 \\
# 2 &  Hverken enig eller uenig &             2 &    356 \\
# 3 &                      Enig &             3 &    401 \\
# 4 &                Meget enig &             4 &    106 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_play}}}
#
# \begin{description}
#   \item[Question]  godt kan lide at tænke over tingene og lege med ideer
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      2 \\
# 1 &                     Uenig &             1 &     30 \\
# 2 &  Hverken enig eller uenig &             2 &    155 \\
# 3 &                      Enig &             3 &    499 \\
# 4 &                Meget enig &             4 &    256 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_quiet}}}
#
# \begin{description}
#   \item[Question]  ofte er stille
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     95 \\
# 1 &                     Uenig &             1 &    245 \\
# 2 &  Hverken enig eller uenig &             2 &    296 \\
# 3 &                      Enig &             3 &    236 \\
# 4 &                Meget enig &             4 &     70 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_relaxed}}}
#
# \begin{description}
#   \item[Question]  er afslappet, god til at håndtere stress
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     22 \\
# 1 &                     Uenig &             1 &    132 \\
# 2 &  Hverken enig eller uenig &             2 &    218 \\
# 3 &                      Enig &             3 &    398 \\
# 4 &                Meget enig &             4 &    172 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_reliable}}}
#
# \begin{description}
#   \item[Question]  er en pålidelig arbejdskraft
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      2 \\
# 1 &                     Uenig &             1 &     21 \\
# 2 &  Hverken enig eller uenig &             2 &    122 \\
# 3 &                      Enig &             3 &    523 \\
# 4 &                Meget enig &             4 &    274 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_reserved}}}
#
# \begin{description}
#   \item[Question]  er reserveret
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    139 \\
# 1 &                     Uenig &             1 &    279 \\
# 2 &  Hverken enig eller uenig &             2 &    300 \\
# 3 &                      Enig &             3 &    193 \\
# 4 &                Meget enig &             4 &     31 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_rude}}}
#
# \begin{description}
#   \item[Question]  nogle gange er uforskammet over for andre
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    178 \\
# 1 &                     Uenig &             1 &    344 \\
# 2 &  Hverken enig eller uenig &             2 &    230 \\
# 3 &                      Enig &             3 &    169 \\
# 4 &                Meget enig &             4 &     21 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_rutine}}}
#
# \begin{description}
#   \item[Question]  foretrækker rutinearbejde
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    125 \\
# 1 &                     Uenig &             1 &    259 \\
# 2 &  Hverken enig eller uenig &             2 &    332 \\
# 3 &                      Enig &             3 &    186 \\
# 4 &                Meget enig &             4 &     40 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_shy}}}
#
# \begin{description}
#   \item[Question]  nogle gange er genert, hæmmet
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     67 \\
# 1 &                     Uenig &             1 &    205 \\
# 2 &  Hverken enig eller uenig &             2 &    224 \\
# 3 &                      Enig &             3 &    373 \\
# 4 &                Meget enig &             4 &     73 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_social}}}
#
# \begin{description}
#   \item[Question]  er udadvendt, social
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     25 \\
# 1 &                     Uenig &             1 &    105 \\
# 2 &  Hverken enig eller uenig &             2 &    247 \\
# 3 &                      Enig &             3 &    388 \\
# 4 &                Meget enig &             4 &    177 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_stable}}}
#
# \begin{description}
#   \item[Question]  er følelsesmæssigt stabil, ikke let at bringe ud af ligevægt
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     26 \\
# 1 &                     Uenig &             1 &    127 \\
# 2 &  Hverken enig eller uenig &             2 &    201 \\
# 3 &                      Enig &             3 &    369 \\
# 4 &                Meget enig &             4 &    219 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_strong\_personality}}}
#
# \begin{description}
#   \item[Question]  har en selvsikker og stærk personlighed
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      7 \\
# 1 &                     Uenig &             1 &    112 \\
# 2 &  Hverken enig eller uenig &             2 &    241 \\
# 3 &                      Enig &             3 &    397 \\
# 4 &                Meget enig &             4 &    185 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_talk}}}
#
# \begin{description}
#   \item[Question]  er snakkesalig
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     15 \\
# 1 &                     Uenig &             1 &    114 \\
# 2 &  Hverken enig eller uenig &             2 &    237 \\
# 3 &                      Enig &             3 &    421 \\
# 4 &                Meget enig &             4 &    155 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_taste\_art}}}
#
# \begin{description}
#   \item[Question]  har en forfinet smag inden for kunst, musik eller litteratur
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    198 \\
# 1 &                     Uenig &             1 &    224 \\
# 2 &  Hverken enig eller uenig &             2 &    246 \\
# 3 &                      Enig &             3 &    181 \\
# 4 &                Meget enig &             4 &     93 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_tense}}}
#
# \begin{description}
#   \item[Question]  kan være anspændt
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &     53 \\
# 1 &                     Uenig &             1 &    263 \\
# 2 &  Hverken enig eller uenig &             2 &    325 \\
# 3 &                      Enig &             3 &    276 \\
# 4 &                Meget enig &             4 &     25 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_unbalanced}}}
#
# \begin{description}
#   \item[Question]  er uligevægtig og nedtrykt
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    383 \\
# 1 &                     Uenig &             1 &    369 \\
# 2 &  Hverken enig eller uenig &             2 &    150 \\
# 3 &                      Enig &             3 &     37 \\
# 4 &                Meget enig &             4 &      3 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_work}}}
#
# \begin{description}
#   \item[Question]  gør sit arbejde grundigt
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &      6 \\
# 1 &                     Uenig &             1 &     59 \\
# 2 &  Hverken enig eller uenig &             2 &    214 \\
# 3 &                      Enig &             3 &    522 \\
# 4 &                Meget enig &             4 &    141 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{bfi\_worry}}}
#
# \begin{description}
#   \item[Question]  bekymrer sig meget
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &               Meget uenig &             0 &    101 \\
# 1 &                     Uenig &             1 &    267 \\
# 2 &  Hverken enig eller uenig &             2 &    230 \\
# 3 &                      Enig &             3 &    266 \\
# 4 &                Meget enig &             4 &     78 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{birthyear}}}
#
# \begin{description}
#   \item[Question]  Hvilket år er du født?
#   \item[Answer type]  \verb|number|
# \end{description}
#
#
# \begin{tabular}{lrrr}
# \toprule
# {} &  response\_index &  answer\_index &  count \\
# \midrule
# 0  &            44.0 &            44 &      1 \\
# 1  &            67.0 &            67 &      1 \\
# 2  &            71.0 &            71 &      1 \\
# 3  &            76.0 &            76 &      1 \\
# 4  &            77.0 &            77 &      1 \\
# 5  &            78.0 &            78 &      1 \\
# 6  &            79.0 &            79 &      1 \\
# 7  &            80.0 &            80 &      6 \\
# 8  &            81.0 &            81 &      4 \\
# 9  &            82.0 &            82 &      4 \\
# 10 &            83.0 &            83 &      4 \\
# 11 &            84.0 &            84 &     10 \\
# 12 &            85.0 &            85 &     10 \\
# 13 &            86.0 &            86 &      6 \\
# 14 &            87.0 &            87 &     15 \\
# 15 &            88.0 &            88 &     26 \\
# 16 &            89.0 &            89 &     51 \\
# 17 &            90.0 &            90 &     74 \\
# 18 &            91.0 &            91 &    146 \\
# 19 &            92.0 &            92 &    258 \\
# 20 &            93.0 &            93 &    227 \\
# 21 &            94.0 &            94 &    103 \\
# 22 &            95.0 &            95 &      2 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{conflicts\_father}}}
#
# \begin{description}
#   \item[Question]  Far
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &           Ofte &             0 &      7 \\
# 1 &      Har ingen &             1 &     26 \\
# 2 &      Af og til &             2 &    156 \\
# 3 &       Sjældent &             3 &    394 \\
# 4 &         Aldrig &             4 &    331 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{conflicts\_friends}}}
#
# \begin{description}
#   \item[Question]  Venner
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &          Altid &             0 &      7 \\
# ...
# \midrule
# 0 &                Nej &             0 &    749 \\
# 1 &   Ja, lidt generet &             1 &    176 \\
# 2 &  Ja, meget generet &             2 &     15 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{symptoms\_eczema}}}
#
# \begin{description}
#   \item[Question]  Eksem, hududslet, kløe
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &     response\_index &  answer\_index &  count \\
# \midrule
# 0 &                Nej &             0 &    824 \\
# 1 &   Ja, lidt generet &             1 &     93 \\
# 2 &  Ja, meget generet &             2 &     23 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{symptoms\_headache}}}
#
# \begin{description}
#   \item[Question]  Hovedpine
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &     response\_index &  answer\_index &  count \\
# \midrule
# 0 &                Nej &             0 &    572 \\
# 1 &   Ja, lidt generet &             1 &    331 \\
# 2 &  Ja, meget generet &             2 &     37 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{symptoms\_indigestion}}}
#
# \begin{description}
#   \item[Question]  Fordøjelsesbesvær, tynd/hård mave
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &     response\_index &  answer\_index &  count \\
# \midrule
# 0 &                Nej &             0 &    768 \\
# 1 &   Ja, lidt generet &             1 &    150 \\
# 2 &  Ja, meget generet &             2 &     22 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{symptoms\_leg}}}
#
# \begin{description}
#   \item[Question]  Smerter/ubehag i arme, ben, knæ, hofter eller led
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &     response\_index &  answer\_index &  count \\
# \midrule
# 0 &                Nej &             0 &    688 \\
# 1 &   Ja, lidt generet &             1 &    206 \\
# 2 &  Ja, meget generet &             2 &     46 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{symptoms\_palpitation}}}
#
# \begin{description}
#   \item[Question]  Hurtig hjertebanken
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &     response\_index &  answer\_index &  count \\
# \midrule
# 0 &                Nej &             0 &    850 \\
# 1 &   Ja, lidt generet &             1 &     83 \\
# 2 &  Ja, meget generet &             2 &      7 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{symptoms\_shoulder}}}
#
# \begin{description}
#   \item[Question]  Smerter/ubehag i skulder/nakke
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &     response\_index &  answer\_index &  count \\
# \midrule
# 0 &                Nej &             0 &    591 \\
# 1 &   Ja, lidt generet &             1 &    300 \\
# 2 &  Ja, meget generet &             2 &     49 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{symptoms\_sleep}}}
#
# \begin{description}
#   \item[Question]  Søvnbesvær, søvnproblemer
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &     response\_index &  answer\_index &  count \\
# \midrule
# 0 &                Nej &             0 &    622 \\
# 1 &   Ja, lidt generet &             1 &    260 \\
# 2 &  Ja, meget generet &             2 &     58 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{symptoms\_stomachache}}}
#
# \begin{description}
#   \item[Question]  Mavesmerter, ondt i maven
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &     response\_index &  answer\_index &  count \\
# \midrule
# 0 &                Nej &             0 &    790 \\
# 1 &   Ja, lidt generet &             1 &    132 \\
# 2 &  Ja, meget generet &             2 &     18 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{symptoms\_tired}}}
#
# \begin{description}
#   \item[Question]  Træthed
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &     response\_index &  answer\_index &  count \\
# \midrule
# 0 &                Nej &             0 &    299 \\
# 1 &   Ja, lidt generet &             1 &    533 \\
# 2 &  Ja, meget generet &             2 &    108 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{talk\_father}}}
#
# \begin{description}
#   \item[Question]  Far
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &          Altid &             0 &    392 \\
# 1 &           Ofte &             1 &    223 \\
# 2 &      Af og til &             2 &    166 \\
# 3 &       Sjældent &             3 &     82 \\
# 4 &         Aldrig &             4 &     50 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{talk\_friends}}}
#
# \begin{description}
#   \item[Question]  Venner
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &          Altid &             0 &    467 \\
# 1 &           Ofte &             1 &    309 \\
# 2 &      Af og til &             2 &    119 \\
# 3 &       Sjældent &             3 &     36 \\
# 4 &         Aldrig &             4 &      8 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{talk\_mother}}}
#
# \begin{description}
#   \item[Question]  Mor
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &          Altid &             0 &    516 \\
# 1 &           Ofte &             1 &    228 \\
# 2 &      Af og til &             2 &    121 \\
# 3 &       Sjældent &             3 &     45 \\
# 4 &         Aldrig &             4 &     22 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{talk\_other\_family}}}
#
# \begin{description}
#   \item[Question]  Øvrig familie
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &          Altid &             0 &    128 \\
# 1 &           Ofte &             1 &    124 \\
# 2 &      Af og til &             2 &    202 \\
# 3 &       Sjældent &             3 &    277 \\
# 4 &         Aldrig &             4 &    200 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{talk\_partner}}}
#
# \begin{description}
#   \item[Question]  Kæreste/ægtefælle
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &      Har ingen &             0 &    365 \\
# 1 &          Altid &             1 &     46 \\
# 2 &           Ofte &             2 &     17 \\
# 3 &         Aldrig &             3 &      2 \\
# 4 &      Af og til &             4 &      6 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{talk\_zieblings}}}
#
# \begin{description}
#   \item[Question]  Søskende
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &          Altid &             0 &    360 \\
# 1 &           Ofte &             1 &    209 \\
# 2 &      Af og til &             2 &    180 \\
# 3 &       Sjældent &             3 &     96 \\
# 4 &         Aldrig &             4 &     49 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{trust\_other}}}
#
# \begin{description}
#   \item[Question]  I hvilken udstrækning er du enig i udsagnet: De fleste folk er til at stole på?
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} &            response\_index &  answer\_index &  count \\
# \midrule
# 0 &                Helt uenig &             0 &     32 \\
# 1 &             Delvist uenig &             1 &    109 \\
# 2 &  Hverken enig eller uenig &             2 &    213 \\
# 3 &              Delvist enig &             3 &    450 \\
# 4 &                 Helt enig &             4 &    129 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{weight}}}
#
# \begin{description}
#   \item[Question]  Hvad vejer du uden tøj? (afrund venligst til nærmeste hele kilogram)
#   \item[Answer type]  \verb|number|
# \end{description}
#
#
# \begin{tabular}{lrrr}
# \toprule
# {} &  response\_index &  answer\_index &  count \\
# \midrule
# 0  &            30.0 &            30 &      1 \\
# 1  &            46.0 &            46 &      2 \\
# 2  &            47.0 &            47 &      1 \\
# 3  &            48.0 &            48 &      3 \\
# 4  &            50.0 &            50 &      9 \\
# 5  &            51.0 &            51 &      5 \\
# 6  &            52.0 &            52 &      6 \\
# 7  &            53.0 &            53 &      7 \\
# 8  &            54.0 &            54 &      5 \\
# 9  &            55.0 &            55 &     10 \\
# 10 &            56.0 &            56 &      9 \\
# 11 &            57.0 &            57 &     11 \\
# 12 &            58.0 &            58 &     12 \\
# 13 &            59.0 &            59 &      8 \\
# 14 &            60.0 &            60 &     32 \\
# 15 &            61.0 &            61 &     15 \\
# 16 &            62.0 &            62 &     18 \\
# 17 &            63.0 &            63 &     20 \\
# 18 &            64.0 &            64 &     15 \\
# 19 &            65.0 &            65 &     49 \\
# 20 &            65.5 &            65 &      1 \\
# 21 &            66.0 &            66 &     14 \\
# 22 &            67.0 &            67 &     30 \\
# 23 &            68.0 &            68 &     31 \\
# 24 &            69.0 &            69 &     15 \\
# 25 &            70.0 &            70 &     56 \\
# 26 &            71.0 &            71 &     18 \\
# 27 &            72.0 &            72 &     26 \\
# 28 &            73.0 &            73 &     27 \\
# 29 &            74.0 &            74 &     26 \\
# 30 &            75.0 &            75 &     54 \\
# 31 &            76.0 &            76 &     23 \\
# 32 &            77.0 &            77 &     18 \\
# 33 &            78.0 &            78 &     28 \\
# 34 &            79.0 &            79 &     13 \\
# 35 &            80.0 &            80 &     59 \\
# 36 &            81.0 &            81 &     11 \\
# 37 &            82.0 &            82 &     26 \\
# 38 &            83.0 &            83 &     17 \\
# 39 &            84.0 &            84 &     14 \\
# 40 &            85.0 &            85 &     25 \\
# 41 &            86.0 &            86 &     11 \\
# 42 &            87.0 &            87 &     10 \\
# 43 &            88.0 &            88 &     16 \\
# 44 &            89.0 &            89 &      7 \\
# 45 &            90.0 &            90 &     24 \\
# 46 &            91.0 &            91 &      5 \\
# 47 &            92.0 &            92 &      9 \\
# 48 &            93.0 &            93 &     13 \\
# 49 &            94.0 &            94 &      2 \\
# 50 &            95.0 &            95 &     23 \\
# 51 &            96.0 &            96 &     11 \\
# 52 &            97.0 &            97 &      4 \\
# 53 &            98.0 &            98 &      1 \\
# 54 &            99.0 &            99 &      2 \\
# 55 &           100.0 &           100 &      9 \\
# 56 &           101.0 &           101 &      2 \\
# 57 &           102.0 &           102 &      1 \\
# 58 &           103.0 &           103 &      2 \\
# 59 &           104.0 &           104 &      1 \\
# 60 &           105.0 &           105 &      4 \\
# 61 &           106.0 &           106 &      1 \\
# 62 &           108.0 &           108 &      3 \\
# 63 &           110.0 &           110 &      3 \\
# 64 &           114.0 &           114 &      1 \\
# 65 &           115.0 &           115 &      2 \\
# 66 &           120.0 &           120 &      2 \\
# 67 &           125.0 &           125 &      1 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{worries\_father}}}
#
# \begin{description}
#   \item[Question]  Far
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &      Har ingen &             0 &     14 \\
# 1 &           Ofte &             1 &     34 \\
# 2 &      Af og til &             2 &    100 \\
# 3 &       Sjældent &             3 &    313 \\
# 4 &         Aldrig &             4 &    452 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{worries\_freinds}}}
#
# \begin{description}
#   \item[Question]  Venner
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &          Altid &             0 &      4 \\
# 1 &           Ofte &             1 &     24 \\
# 2 &      Af og til &             2 &    198 \\
# 3 &       Sjældent &             3 &    374 \\
# 4 &         Aldrig &             4 &    341 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{worries\_mother}}}
#
# \begin{description}
#   \item[Question]  Mor
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &          Altid &             0 &     15 \\
# 1 &           Ofte &             1 &     33 \\
# 2 &      Af og til &             2 &    125 \\
# 3 &       Sjældent &             3 &    334 \\
# 4 &         Aldrig &             4 &    424 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{worries\_other\_family}}}
#
# \begin{description}
#   \item[Question]  Øvrig familie
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &           Ofte &             0 &      5 \\
# 1 &      Har ingen &             1 &      9 \\
# 2 &      Af og til &             2 &     91 \\
# 3 &       Sjældent &             3 &    279 \\
# 4 &         Aldrig &             4 &    544 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{worries\_partner}}}
#
# \begin{description}
#   \item[Question]  Kæreste/ægtefælle
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &           Ofte &             0 &      6 \\
# 1 &      Af og til &             1 &     25 \\
# 2 &         Aldrig &             2 &    113 \\
# 3 &      Har ingen &             3 &    155 \\
# 4 &       Sjældent &             4 &    141 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
#
# \begin{minipage}{0.4\textwidth}
# \vspace{1cm}
# \section*{\texttt{\textbf{worries\_zieblings}}}
#
# \begin{description}
#   \item[Question]  Søskende
#   \item[Answer type]  \verb|radio|
# \end{description}
#
#
# \begin{tabular}{llrr}
# \toprule
# {} & response\_index &  answer\_index &  count \\
# \midrule
# 0 &           Ofte &             0 &     17 \\
# 1 &      Har ingen &             1 &     37 \\
# 2 &      Af og til &             2 &    115 \\
# 3 &       Sjældent &             3 &    301 \\
# 4 &         Aldrig &             4 &    422 \\
# \bottomrule
# \end{tabular}
#
#  \end{minipage}
#
#
# \end{document}
