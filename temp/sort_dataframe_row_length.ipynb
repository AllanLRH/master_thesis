# %%
import pandas as pd
import numpy as np

# %%
s = 'ABCDEFGH'
df = pd.DataFrame([tuple(s[:k*i]) for i in range(3,7) for k in [1, -1]])
df
# Out:
#    0  1     2     3     4     5
# 0  A  B     C  None  None  None
# 1  A  B     C     D     E  None
# 2  A  B     C     D  None  None
# 3  A  B     C     D  None  None
# 4  A  B     C     D     E  None
# 5  A  B     C  None  None  None
# 6  A  B     C     D     E     F
# 7  A  B  None  None  None  None

# %%
df.iloc[np.argsort(df.count(axis=1))[::-1]].reset_index(drop=True)
# Out:
#    0  1     2     3     4     5
# 0  A  B     C     D     E     F
# 1  A  B     C     D     E  None
# 2  A  B     C     D     E  None
# 3  A  B     C     D  None  None
# 4  A  B     C     D  None  None
# 5  A  B     C  None  None  None
# 6  A  B     C  None  None  None
# 7  A  B  None  None  None  None
